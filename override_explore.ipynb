# %%
import pandas as pd
men_prob = pd.read_csv('matchupProbabilities_men.csv')
women_prob = pd.read_csv('matchupProbabilities_women.csv')

# %%
duke_row = men_prob[men_prob['T1_TeamName'] == 'Duke']
duke_row[['T2_TeamID', 'Pred']]
# Out:
#      T2_TeamID      Pred
# 448       1196  0.614148
# 449       1202  0.981868
# 450       1208  0.895665
# 451       1211  0.755901
# 452       1218  0.976784
# ..         ...       ...
# 503       1438  0.797876
# 504       1458  0.863767
# 505       1460  0.983576
# 506       1465  0.960916
# 507       1474  0.985547
#
# [60 rows x 2 columns]
