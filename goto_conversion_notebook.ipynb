# %%
# %pip install goto-conversion==4.0.1
import goto_conversion.outputFiles as of
from importlib.resources import files
import pandas as pd
df = pd.read_csv(files(of) / 'gotoConversion.csv')
df.to_csv('matchupProbabilities.csv')
# Out:
# ...
#   Using cached goto_conversion-4.0.1-py3-none-any.whl.metadata (7.1 kB)
# Using cached goto_conversion-4.0.1-py3-none-any.whl (754 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
